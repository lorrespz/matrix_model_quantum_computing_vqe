# %% [markdown]
# # $\Lambda = 4, \lambda = 0.2$: EvolvedOperatorAnsatz
#
# Notebook created by HLD for the work arXiv: 2503.13368 [quant-ph, hep-th]
#
# In this notebook, we run the VQE experiments for bosonic SU(2) matrix model at $\Lambda = 4, \lambda = 0.2$ using different variants of EvolvedOperatorAnsatz with the fixed Estimator seed = 225.

# %%
import sys
sys.path.append('../../utility')
from vqe_run import *
from qc_ansatze import *
from L4_evop_func import *

# %%
l4_l02_evop = L4_evop(0.2)
# Out:
# Min absolute value is 0.000897
# Max absolute value is 1.15
# Mean absolute value is 0.03431
# None
# E_exact = 3.13406

# %%
[print(f'{l4_l02_evop.ansatz_names[i]}: {l4_l02_evop.ansatz_list[i].num_parameters}') for i in range(len(l4_l02_evop.ansatz_list))]
# Out:
# ev_op_Hp15: 15
# ev_op_Hp20: 20
# ev_op_Hp25: 25
# ev_op_Hp30: 30
# ev_op_H40: 40
# ev_op_Hp15_2f: 30
# ev_op_Hp20_2f: 40
# ev_op_Hp25_2f: 50
# ev_op_Hp30_2f: 60
# ev_op_Hp40_2f: 80
# [None, None, None, None, None, None, None, None, None, None]

# %%
#l4_l02_evop.ansatz_list[1].decompose().draw(output = 'mpl')

# %%
H4q = l4_l02_evop.H4q

# %% [markdown]
# # VQE individual runs

# %%
seed = 225
iterations = 650
algorithm_globals.random_seed = seed

#estimator
noiseless_estimator = AerEstimator(
    run_options={"seed": seed, "shots": 1024},
    transpile_options={"seed_transpiler": seed},
)
#storing values
counts = []
values = []
def store_intermediate_result(eval_count, parameters, mean, std):
    counts.append(eval_count)
    values.append(mean)
    
def run_qve_w_specified_optimizer(optimizer, ansatz):
    opt = optimizer(maxiter = iterations)
    vqe = VQE(noiseless_estimator, ansatz, optimizer=opt, callback=store_intermediate_result)
    result = vqe.compute_minimum_eigenvalue(operator=H4q).eigenvalue.real
    print(f"VQE result: {result:.5f}")
    return result

# %% [markdown]
# # COBYLA

# %%
r_cobyla=[]
for i in range(len(l4_l02_evop.ansatz_list)):
    print(f'At step {i}, with {l4_l02_evop.ansatz_names[i]}')
    counts = []
    values = []
    t0 = time.time()
    result = run_qve_w_specified_optimizer(COBYLA, l4_l02_evop.ansatz_list[i])
    t1 = time.time()
    print(f'Length of this optimization {len(values)}, time taken = {np.round(t1-t0,3)} \n')
    counts_a = counts
    values_a = values 
    r_cobyla.append(pd.DataFrame({f'{l4_l02_evop.ansatz_names[i]}': values_a}))
# Out:
# At step 0, with ev_op_Hp15
# VQE result: 3.05555
# Length of this optimization 180, time taken = 159.707
#
# At step 1, with ev_op_Hp20
# VQE result: 3.18835
# Length of this optimization 229, time taken = 239.088
#
# At step 2, with ev_op_Hp25
# VQE result: 3.10279
# Length of this optimization 315, time taken = 353.844
#
# At step 3, with ev_op_Hp30
# VQE result: 3.21665
# Length of this optimization 431, time taken = 516.896
#
# At step 4, with ev_op_H40
# VQE result: 3.29301
# Length of this optimization 544, time taken = 905.043
#
# At step 5, with ev_op_Hp15_2f
# VQE result: 3.15952
# Length of this optimization 401, time taken = 422.48
#
# At step 6, with ev_op_Hp20_2f
# VQE result: 3.27433
# Length of this optimization 417, time taken = 561.587
#
# At step 7, with ev_op_Hp25_2f
# VQE result: 3.34268
# Length of this optimization 650, time taken = 998.512
#
# At step 8, with ev_op_Hp30_2f
# VQE result: 3.49113
# Length of this optimization 650, time taken = 1117.866
#
# ...

# %%
df1 = pd.concat([r_cobyla[i] for i in range(len(r_cobyla))], axis = 1)
df1.to_csv('l4_l02_op_ev_20_30_40_indv_cobyla_seed225.csv')

# %% [markdown]
# # SPSA

# %%
r_spsa=[]
for i in range(len(l4_l02_evop.ansatz_list)):
    print(f'At step {i}, with {l4_l02_evop.ansatz_names[i]}')
    counts = []
    values = []
    t0 = time.time()
    result = run_qve_w_specified_optimizer(SPSA, l4_l02_evop.ansatz_list[i])
    t1 = time.time()
    print(f'Length of this optimization {len(values)}, time taken = {np.round(t1-t0,3)} \n')
    counts_a = counts
    values_a = values 
    r_spsa.append(pd.DataFrame({f'{l4_l02_evop.ansatz_names[i]}': values_a}))
# Out:
# At step 0, with ev_op_Hp15
# VQE result: 3.17320
# Length of this optimization 1351, time taken = 1472.828
#
# At step 1, with ev_op_Hp20
# VQE result: 3.13040
# Length of this optimization 1351, time taken = 1653.064
#
# At step 2, with ev_op_Hp25
# VQE result: 3.16583
# Length of this optimization 1351, time taken = 1781.985
#
# At step 3, with ev_op_Hp30
# VQE result: 3.14084
# Length of this optimization 1351, time taken = 1820.834
#
# At step 4, with ev_op_H40
# VQE result: 3.26369
# Length of this optimization 1351, time taken = 2517.33
#
# At step 5, with ev_op_Hp15_2f
# VQE result: 3.15614
# Length of this optimization 1351, time taken = 1704.643
#
# At step 6, with ev_op_Hp20_2f
# VQE result: 3.11968
# Length of this optimization 1351, time taken = 2098.423
#
# At step 7, with ev_op_Hp25_2f
# VQE result: 3.13421
# Length of this optimization 1351, time taken = 2262.785
#
# At step 8, with ev_op_Hp30_2f
# VQE result: 3.15462
# ...

# %%
df2 = pd.concat([r_spsa[i] for i in range(len(r_spsa))], axis = 1)
df2.to_csv('l4_l02_op_ev_20_30_40_indv_spsa_seed225.csv')
