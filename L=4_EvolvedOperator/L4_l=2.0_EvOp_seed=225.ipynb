# %% [markdown]
# # $\Lambda = 4, \lambda = 2.0$: EvolvedOperatorAnsatz
#
# Notebook created by HLD for the work arXiv: 2503.13368 [quant-ph, hep-th]
#
# In this notebook, we run the VQE experiments for bosonic SU(2) matrix model at $\Lambda = 4, \lambda = 2.0$ using different variants of EvolvedOperatorAnsatz with the fixed Estimator seed = 225.

# %%
import sys
sys.path.append('../../utility')
from vqe_run import *
from qc_ansatze import *
from L4_evop_func import *

# %%
l4_evop = L4_evop(2.0)
# Out:
# Min absolute value is 0.008975
# Max absolute value is 2.89778
# Mean absolute value is 0.25249
# None
# E_exact = 3.89548

# %%
[print(f'{l4_evop.ansatz_names[i]}: {l4_evop.ansatz_list[i].num_parameters}') for i in range(len(l4_evop.ansatz_list))]
# Out:
# ev_op_Hp15: 15
# ev_op_Hp20: 20
# ev_op_Hp25: 25
# ev_op_Hp30: 30
# ev_op_H40: 40
# ev_op_Hp15_2f: 30
# ev_op_Hp20_2f: 40
# ev_op_Hp25_2f: 50
# ev_op_Hp30_2f: 60
# ev_op_Hp40_2f: 80
# [None, None, None, None, None, None, None, None, None, None]

# %%
#l4_l02_evop.ansatz_list[1].decompose().draw(output = 'mpl')

# %%
H4q = l4_evop.H4q

# %% [markdown]
# # VQE individual runs

# %%
seed = 225
iterations = 650
algorithm_globals.random_seed = seed

#estimator
noiseless_estimator = AerEstimator(
    run_options={"seed": seed, "shots": 1024},
    transpile_options={"seed_transpiler": seed},
)
#storing values
counts = []
values = []
def store_intermediate_result(eval_count, parameters, mean, std):
    counts.append(eval_count)
    values.append(mean)
    
def run_qve_w_specified_optimizer(optimizer, ansatz):
    opt = optimizer(maxiter = iterations)
    vqe = VQE(noiseless_estimator, ansatz, optimizer=opt, callback=store_intermediate_result)
    result = vqe.compute_minimum_eigenvalue(operator=H4q).eigenvalue.real
    print(f"VQE result: {result:.5f}")
    return result

# %% [markdown]
# # COBYLA

# %%
r_cobyla=[]
for i in range(len(l4_evop.ansatz_list)):
    print(f'At step {i}, with {l4_evop.ansatz_names[i]}')
    counts = []
    values = []
    t0 = time.time()
    result = run_qve_w_specified_optimizer(COBYLA, l4_evop.ansatz_list[i])
    t1 = time.time()
    print(f'Length of this optimization {len(values)}, time taken = {np.round(t1-t0,3)} \n')
    counts_a = counts
    values_a = values 
    r_cobyla.append(pd.DataFrame({f'{l4_evop.ansatz_names[i]}': values_a}))
# Out:
# At step 0, with ev_op_Hp15
# VQE result: 4.86152
# Length of this optimization 159, time taken = 192.882
#
# At step 1, with ev_op_Hp20
# VQE result: 4.16425
# Length of this optimization 238, time taken = 281.38
#
# At step 2, with ev_op_Hp25
# VQE result: 6.55027
# Length of this optimization 271, time taken = 350.473
#
# At step 3, with ev_op_Hp30
# VQE result: 5.60822
# Length of this optimization 354, time taken = 534.399
#
# At step 4, with ev_op_H40
# VQE result: 17.64434
# Length of this optimization 459, time taken = 1062.126
#
# At step 5, with ev_op_Hp15_2f
# VQE result: 4.94432
# Length of this optimization 296, time taken = 443.558
#
# At step 6, with ev_op_Hp20_2f
# VQE result: 4.93465
# Length of this optimization 468, time taken = 732.005
#
# At step 7, with ev_op_Hp25_2f
# VQE result: 9.06763
# Length of this optimization 607, time taken = 1040.958
#
# At step 8, with ev_op_Hp30_2f
# VQE result: 6.28413
# Length of this optimization 650, time taken = 1445.143
#
# At step 9, with ev_op_Hp40_2f
# VQE result: 20.62664
# Length of this optimization 650, time taken = 2235.602

# %%
df1 = pd.concat([r_cobyla[i] for i in range(len(r_cobyla))], axis = 1)
df1.to_csv('l4_l20_op_ev_cobyla_seed225.csv')

# %% [markdown]
# # SPSA

# %%
r_spsa=[]
for i in range(len(l4_evop.ansatz_list)):
    print(f'At step {i}, with {l4_evop.ansatz_names[i]}')
    counts = []
    values = []
    t0 = time.time()
    result = run_qve_w_specified_optimizer(SPSA, l4_evop.ansatz_list[i])
    t1 = time.time()
    print(f'Length of this optimization {len(values)}, time taken = {np.round(t1-t0,3)} \n')
    counts_a = counts
    values_a = values 
    r_spsa.append(pd.DataFrame({f'{l4_evop.ansatz_names[i]}': values_a}))
# Out:
# At step 0, with ev_op_Hp15
# VQE result: 4.69522
# Length of this optimization 1351, time taken = 1673.489
#
# At step 1, with ev_op_Hp20
# VQE result: 4.62906
# Length of this optimization 1351, time taken = 1703.117
#
# At step 2, with ev_op_Hp25
# VQE result: 4.37152
# Length of this optimization 1351, time taken = 1892.719
#
# At step 3, with ev_op_Hp30
# VQE result: 4.12944
# Length of this optimization 1351, time taken = 2164.966
#
# At step 4, with ev_op_H40
# VQE result: 6.29502
# Length of this optimization 1351, time taken = 2762.573
#
# At step 5, with ev_op_Hp15_2f
# VQE result: 3.93348
# Length of this optimization 1351, time taken = 2040.619
#
# At step 6, with ev_op_Hp20_2f
# VQE result: 4.43587
# Length of this optimization 1351, time taken = 33305.862
#
# At step 7, with ev_op_Hp25_2f
# VQE result: 4.51453
# Length of this optimization 1351, time taken = 2275.555
#
# At step 8, with ev_op_Hp30_2f
# VQE result: 7.52214
# Length of this optimization 1351, time taken = 2791.968
#
# At step 9, with ev_op_Hp40_2f
# VQE result: 9.82824
# Length of this optimization 1351, time taken = 3739.661

# %%
df2 = pd.concat([r_spsa[i] for i in range(len(r_spsa))], axis = 1)
df2.to_csv('l4_l20_op_ev_spsa_seed225.csv')
