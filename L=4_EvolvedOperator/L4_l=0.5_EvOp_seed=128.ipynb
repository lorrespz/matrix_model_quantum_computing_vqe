# %% [markdown]
# # $\Lambda = 4, \lambda = 0.5$: EvolvedOperatorAnsatz
#
# Notebook created by HLD for the work arXiv: 2503.13368 [quant-ph, hep-th]
#
# In this notebook, we run the VQE experiments for bosonic SU(2) matrix model at $\Lambda = 4, \lambda = 0.5$ using different variants of EvolvedOperatorAnsatz with the fixed Estimator seed = 128.

# %%
import sys
sys.path.append('../../utility')
from vqe_run import *
from qc_ansatze import *
from L4_evop_func import *

# %%
l4_evop = L4_evop(0.5)
# Out:
# Min absolute value is 0.002244
# Max absolute value is 1.375
# Mean absolute value is 0.07067
# None
# E_exact = 3.29894

# %%
[print(f'{l4_evop.ansatz_names[i]}: {l4_evop.ansatz_list[i].num_parameters}') for i in range(len(l4_evop.ansatz_list))]
# Out:
# ev_op_Hp15: 15
# ev_op_Hp20: 20
# ev_op_Hp25: 25
# ev_op_Hp30: 30
# ev_op_H40: 40
# ev_op_Hp15_2f: 30
# ev_op_Hp20_2f: 40
# ev_op_Hp25_2f: 50
# ev_op_Hp30_2f: 60
# ev_op_Hp40_2f: 80
# [None, None, None, None, None, None, None, None, None, None]

# %%
#l4_l02_evop.ansatz_list[1].decompose().draw(output = 'mpl')

# %%
H4q = l4_evop.H4q

# %% [markdown]
# # VQE individual runs

# %%
seed = 128
iterations = 650
algorithm_globals.random_seed = seed

#estimator
noiseless_estimator = AerEstimator(
    run_options={"seed": seed, "shots": 1024},
    transpile_options={"seed_transpiler": seed},
)
#storing values
counts = []
values = []
def store_intermediate_result(eval_count, parameters, mean, std):
    counts.append(eval_count)
    values.append(mean)
    
def run_qve_w_specified_optimizer(optimizer, ansatz):
    opt = optimizer(maxiter = iterations)
    vqe = VQE(noiseless_estimator, ansatz, optimizer=opt, callback=store_intermediate_result)
    result = vqe.compute_minimum_eigenvalue(operator=H4q).eigenvalue.real
    print(f"VQE result: {result:.5f}")
    return result

# %% [markdown]
# # COBYLA

# %%
r_cobyla=[]
for i in range(len(l4_evop.ansatz_list)):
    print(f'At step {i}, with {l4_evop.ansatz_names[i]}')
    counts = []
    values = []
    t0 = time.time()
    result = run_qve_w_specified_optimizer(COBYLA, l4_evop.ansatz_list[i])
    t1 = time.time()
    print(f'Length of this optimization {len(values)}, time taken = {np.round(t1-t0,3)} \n')
    counts_a = counts
    values_a = values 
    r_cobyla.append(pd.DataFrame({f'{l4_evop.ansatz_names[i]}': values_a}))
# Out:
# At step 0, with ev_op_Hp15
# VQE result: 4.03464
# Length of this optimization 147, time taken = 150.513
#
# At step 1, with ev_op_Hp20
# VQE result: 3.17457
# Length of this optimization 279, time taken = 311.938
#
# At step 2, with ev_op_Hp25
# VQE result: 3.60329
# Length of this optimization 284, time taken = 368.599
#
# At step 3, with ev_op_Hp30
# VQE result: 3.51242
# Length of this optimization 414, time taken = 541.117
#
# At step 4, with ev_op_H40
# VQE result: 3.87004
# Length of this optimization 511, time taken = 949.414
#
# At step 5, with ev_op_Hp15_2f
# VQE result: 3.31729
# Length of this optimization 323, time taken = 373.165
#
# At step 6, with ev_op_Hp20_2f
# VQE result: 3.25157
# Length of this optimization 497, time taken = 711.723
#
# At step 7, with ev_op_Hp25_2f
# VQE result: 3.39117
# Length of this optimization 640, time taken = 1041.567
#
# At step 8, with ev_op_Hp30_2f
# VQE result: 3.71606
# Length of this optimization 650, time taken = 1200.388
#
# At step 9, with ev_op_Hp40_2f
# VQE result: 9.11650
# Length of this optimization 650, time taken = 1876.393

# %%
df1 = pd.concat([r_cobyla[i] for i in range(len(r_cobyla))], axis = 1)
df1.to_csv('l4_l05_op_ev_20_30_40_indv_cobyla_seed128.csv')

# %% [markdown]
# # SPSA

# %%
r_spsa=[]
for i in range(len(l4_evop.ansatz_list)):
    print(f'At step {i}, with {l4_evop.ansatz_names[i]}')
    counts = []
    values = []
    t0 = time.time()
    result = run_qve_w_specified_optimizer(SPSA, l4_evop.ansatz_list[i])
    t1 = time.time()
    print(f'Length of this optimization {len(values)}, time taken = {np.round(t1-t0,3)} \n')
    counts_a = counts
    values_a = values 
    r_spsa.append(pd.DataFrame({f'{l4_evop.ansatz_names[i]}': values_a}))
# Out:
# At step 0, with ev_op_Hp15
# VQE result: 3.24542
# Length of this optimization 1351, time taken = 1613.426
#
# At step 1, with ev_op_Hp20
# VQE result: 3.30692
# Length of this optimization 1351, time taken = 1765.695
#
# At step 2, with ev_op_Hp25
# VQE result: 3.28458
# Length of this optimization 1351, time taken = 1881.634
#
# At step 3, with ev_op_Hp30
# VQE result: 3.30621
# Length of this optimization 1351, time taken = 2100.237
#
# At step 4, with ev_op_H40
# VQE result: 3.35059
# Length of this optimization 1351, time taken = 2501.673
#
# At step 5, with ev_op_Hp15_2f
# VQE result: 3.34375
# Length of this optimization 1351, time taken = 1819.935
#
# At step 6, with ev_op_Hp20_2f
# VQE result: 3.29136
# Length of this optimization 1351, time taken = 2133.106
#
# At step 7, with ev_op_Hp25_2f
# VQE result: 3.29896
# Length of this optimization 1351, time taken = 2256.634
#
# At step 8, with ev_op_Hp30_2f
# VQE result: 3.33945
# Length of this optimization 1351, time taken = 2554.696
#
# At step 9, with ev_op_Hp40_2f
# VQE result: 10.99971
# Length of this optimization 1351, time taken = 3671.847

# %%
df2 = pd.concat([r_spsa[i] for i in range(len(r_spsa))], axis = 1)
df2.to_csv('l4_l05_op_ev_20_30_40_indv_spsa_seed128.csv')
